# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('data/dataset.csv')
ds.head(10)
# Out:
#   Disease            Symptom_0            Symptom_1                Symptom_2  \
# 0    AIDS       muscle_wasting    patches_in_throat               high_fever
# 1    AIDS    patches_in_throat           high_fever   extra_marital_contacts
# 2    AIDS       muscle_wasting           high_fever   extra_marital_contacts
# 3    AIDS       muscle_wasting    patches_in_throat   extra_marital_contacts
# 4    AIDS       muscle_wasting    patches_in_throat               high_fever
# 5    Acne            skin_rash   pus_filled_pimples               blackheads
# 6    Acne   pus_filled_pimples           blackheads                scurrying
# 7    Acne            skin_rash           blackheads                scurrying
# 8    Acne            skin_rash   pus_filled_pimples                scurrying
# 9    Acne            skin_rash   pus_filled_pimples               blackheads
#
#                  Symptom_3 Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8  \
# 0   extra_marital_contacts       NaN       NaN       NaN       NaN       NaN
# 1                      NaN       NaN       NaN       NaN       NaN       NaN
# 2                      NaN       NaN       NaN       NaN       NaN       NaN
# 3                      NaN       NaN       NaN       NaN       NaN       NaN
# 4                      NaN       NaN       NaN       NaN       NaN       NaN
# 5                scurrying       NaN       NaN       NaN       NaN       NaN
# 6                      NaN       NaN       NaN       NaN       NaN       NaN
# 7                      NaN       NaN       NaN       NaN       NaN       NaN
# 8                      NaN       NaN       NaN       NaN       NaN       NaN
# 9                      NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_9 Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 5       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 6       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 7       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 8       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 9       NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %%
ds.replace('null', np.nan, inplace=True)

# %%
ds.head()
# Out:
#   Disease           Symptom_0           Symptom_1                Symptom_2  \
# 0    AIDS      muscle_wasting   patches_in_throat               high_fever
# 1    AIDS   patches_in_throat          high_fever   extra_marital_contacts
# 2    AIDS      muscle_wasting          high_fever   extra_marital_contacts
# 3    AIDS      muscle_wasting   patches_in_throat   extra_marital_contacts
# 4    AIDS      muscle_wasting   patches_in_throat               high_fever
#
#                  Symptom_3 Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8  \
# 0   extra_marital_contacts       NaN       NaN       NaN       NaN       NaN
# 1                      NaN       NaN       NaN       NaN       NaN       NaN
# 2                      NaN       NaN       NaN       NaN       NaN       NaN
# 3                      NaN       NaN       NaN       NaN       NaN       NaN
# 4                      NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_9 Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4       NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
ds['Disease'] = le.fit_transform(ds['Disease'])
ds.head(30)
# Out:
#     Disease             Symptom_0            Symptom_1  \
# 0         0        muscle_wasting    patches_in_throat
# 1         0     patches_in_throat           high_fever
# 2         0        muscle_wasting           high_fever
# 3         0        muscle_wasting    patches_in_throat
# 4         0        muscle_wasting    patches_in_throat
# 5         1             skin_rash   pus_filled_pimples
# 6         1    pus_filled_pimples           blackheads
# 7         1             skin_rash           blackheads
# 8         1             skin_rash   pus_filled_pimples
# 9         1             skin_rash   pus_filled_pimples
# 10        2              vomiting       yellowish_skin
# 11        2        yellowish_skin       abdominal_pain
# 12        2              vomiting       yellowish_skin
# 13        2              vomiting       yellowish_skin
# 14        2              vomiting       yellowish_skin
# 15        2              vomiting       yellowish_skin
# 16        2              vomiting       abdominal_pain
# 17        2              vomiting       yellowish_skin
# 18        3             shivering               chills
# 19        3   continuous_sneezing            shivering
# 20        3   continuous_sneezing            shivering
# 21        3   continuous_sneezing            shivering
# 22        3   continuous_sneezing               chills
# 23        4       muscle_weakness           stiff_neck
# 24        4            stiff_neck      swelling_joints
# 25        4       muscle_weakness      swelling_joints
# 26        4       muscle_weakness           stiff_neck
# 27        4       muscle_weakness           stiff_neck
# 28        4       muscle_weakness           stiff_neck
# 29        5               fatigue                cough
#
#                   Symptom_2                Symptom_3  \
# 0                high_fever   extra_marital_contacts
# 1    extra_marital_contacts                      NaN
# 2    extra_marital_contacts                      NaN
# 3    extra_marital_contacts                      NaN
# 4                high_fever                      NaN
# 5                blackheads                scurrying
# 6                 scurrying                      NaN
# 7                 scurrying                      NaN
# 8                 scurrying                      NaN
# 9                blackheads                      NaN
# 10      swelling_of_stomach    distention_of_abdomen
# 11      swelling_of_stomach    distention_of_abdomen
# 12           abdominal_pain      swelling_of_stomach
# 13           abdominal_pain      swelling_of_stomach
# 14           abdominal_pain      swelling_of_stomach
# 15           abdominal_pain    distention_of_abdomen
# 16      swelling_of_stomach    distention_of_abdomen
# 17           abdominal_pain      swelling_of_stomach
# 18       watering_from_eyes                      NaN
# 19       watering_from_eyes                      NaN
# 20                   chills                      NaN
# 21                   chills       watering_from_eyes
# 22       watering_from_eyes                      NaN
# 23          swelling_joints       movement_stiffness
# 24       movement_stiffness          painful_walking
# 25       movement_stiffness          painful_walking
# 26       movement_stiffness          painful_walking
# 27          swelling_joints          painful_walking
# 28          swelling_joints       movement_stiffness
# 29               high_fever           breathlessness
#
#                           Symptom_4                        Symptom_5  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                               NaN                              NaN
# 10   history_of_alcohol_consumption                   fluid_overload
# 11   history_of_alcohol_consumption                   fluid_overload
# 12            distention_of_abdomen   history_of_alcohol_consumption
# 13            distention_of_abdomen                   fluid_overload
# 14   history_of_alcohol_consumption                   fluid_overload
# 15   history_of_alcohol_consumption                   fluid_overload
# 16   history_of_alcohol_consumption                   fluid_overload
# 17            distention_of_abdomen   history_of_alcohol_consumption
# 18                              NaN                              NaN
# 19                              NaN                              NaN
# 20                              NaN                              NaN
# 21                              NaN                              NaN
# 22                              NaN                              NaN
# 23                  painful_walking                              NaN
# 24                              NaN                              NaN
# 25                              NaN                              NaN
# 26                              NaN                              NaN
# 27                              NaN                              NaN
# 28                              NaN                              NaN
# 29                   family_history                    mucoid_sputum
#
#           Symptom_6 Symptom_7 Symptom_8 Symptom_9 Symptom_10 Symptom_11  \
# 0               NaN       NaN       NaN       NaN        NaN        NaN
# 1               NaN       NaN       NaN       NaN        NaN        NaN
# 2               NaN       NaN       NaN       NaN        NaN        NaN
# 3               NaN       NaN       NaN       NaN        NaN        NaN
# 4               NaN       NaN       NaN       NaN        NaN        NaN
# 5               NaN       NaN       NaN       NaN        NaN        NaN
# 6               NaN       NaN       NaN       NaN        NaN        NaN
# 7               NaN       NaN       NaN       NaN        NaN        NaN
# 8               NaN       NaN       NaN       NaN        NaN        NaN
# 9               NaN       NaN       NaN       NaN        NaN        NaN
# 10              NaN       NaN       NaN       NaN        NaN        NaN
# 11              NaN       NaN       NaN       NaN        NaN        NaN
# 12              NaN       NaN       NaN       NaN        NaN        NaN
# 13              NaN       NaN       NaN       NaN        NaN        NaN
# 14              NaN       NaN       NaN       NaN        NaN        NaN
# 15              NaN       NaN       NaN       NaN        NaN        NaN
# 16              NaN       NaN       NaN       NaN        NaN        NaN
# 17   fluid_overload       NaN       NaN       NaN        NaN        NaN
# 18              NaN       NaN       NaN       NaN        NaN        NaN
# 19              NaN       NaN       NaN       NaN        NaN        NaN
# 20              NaN       NaN       NaN       NaN        NaN        NaN
# 21              NaN       NaN       NaN       NaN        NaN        NaN
# 22              NaN       NaN       NaN       NaN        NaN        NaN
# 23              NaN       NaN       NaN       NaN        NaN        NaN
# 24              NaN       NaN       NaN       NaN        NaN        NaN
# 25              NaN       NaN       NaN       NaN        NaN        NaN
# 26              NaN       NaN       NaN       NaN        NaN        NaN
# 27              NaN       NaN       NaN       NaN        NaN        NaN
# 28              NaN       NaN       NaN       NaN        NaN        NaN
# 29              NaN       NaN       NaN       NaN        NaN        NaN
#
#    Symptom_12 Symptom_13 Symptom_14 Symptom_15 Symptom_16
# 0         NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN        NaN
# 13        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN
# 16        NaN        NaN        NaN        NaN        NaN
# 17        NaN        NaN        NaN        NaN        NaN
# 18        NaN        NaN        NaN        NaN        NaN
# 19        NaN        NaN        NaN        NaN        NaN
# 20        NaN        NaN        NaN        NaN        NaN
# 21        NaN        NaN        NaN        NaN        NaN
# 22        NaN        NaN        NaN        NaN        NaN
# 23        NaN        NaN        NaN        NaN        NaN
# 24        NaN        NaN        NaN        NaN        NaN
# 25        NaN        NaN        NaN        NaN        NaN
# 26        NaN        NaN        NaN        NaN        NaN
# 27        NaN        NaN        NaN        NaN        NaN
# 28        NaN        NaN        NaN        NaN        NaN
# 29        NaN        NaN        NaN        NaN        NaN

# %%
symptom_columns = ds.columns[ds.columns != 'Disease']
df = pd.get_dummies(ds, columns=symptom_columns)

# %%
df.head(60)
# Out:
#     Disease  Symptom_0_ acidity  Symptom_0_ back_pain  \
# 0         0               False                 False
# 1         0               False                 False
# 2         0               False                 False
# 3         0               False                 False
# 4         0               False                 False
# 5         1               False                 False
# 6         1               False                 False
# 7         1               False                 False
# 8         1               False                 False
# 9         1               False                 False
# 10        2               False                 False
# 11        2               False                 False
# 12        2               False                 False
# 13        2               False                 False
# 14        2               False                 False
# 15        2               False                 False
# 16        2               False                 False
# 17        2               False                 False
# 18        3               False                 False
# 19        3               False                 False
# 20        3               False                 False
# 21        3               False                 False
# 22        3               False                 False
# 23        4               False                 False
# 24        4               False                 False
# 25        4               False                 False
# 26        4               False                 False
# 27        4               False                 False
# 28        4               False                 False
# 29        5               False                 False
# 30        5               False                 False
# 31        5               False                 False
# 32        5               False                 False
# 33        5               False                 False
# 34        5               False                 False
# 35        5               False                 False
# 36        6               False                  True
# 37        6               False                 False
# 38        6               False                  True
# 39        6               False                  True
# 40        6               False                  True
# 41        6               False                  True
# 42        7               False                 False
# 43        7               False                 False
# 44        7               False                 False
# 45        7               False                 False
# 46        7               False                 False
# 47        7               False                 False
# 48        7               False                 False
# 49        7               False                 False
# 50        7               False                 False
# 51        7               False                 False
# 52        8               False                 False
# 53        8               False                 False
# 54        8               False                 False
# 55        8               False                 False
# 56        8               False                 False
# 57        8               False                 False
# 58        8               False                 False
# 59        8               False                 False
#
#     Symptom_0_ bladder_discomfort  Symptom_0_ breathlessness  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# 5                           False                      False
# 6                           False                      False
# 7                           False                      False
# 8                           False                      False
# 9                           False                      False
# 10                          False                      False
# 11                          False                      False
# 12                          False                      False
# 13                          False                      False
# 14                          False                      False
# 15                          False                      False
# 16                          False                      False
# 17                          False                      False
# 18                          False                      False
# 19                          False                      False
# 20                          False                      False
# 21                          False                      False
# 22                          False                      False
# 23                          False                      False
# 24                          False                      False
# 25                          False                      False
# 26                          False                      False
# 27                          False                      False
# 28                          False                      False
# 29                          False                      False
# 30                          False                      False
# 31                          False                      False
# 32                          False                      False
# 33                          False                      False
# 34                          False                      False
# 35                          False                      False
# 36                          False                      False
# 37                          False                      False
# 38                          False                      False
# 39                          False                      False
# 40                          False                      False
# 41                          False                      False
# 42                          False                      False
# 43                          False                      False
# 44                          False                      False
# 45                          False                      False
# 46                          False                      False
# 47                          False                      False
# 48                          False                      False
# 49                          False                      False
# 50                          False                      False
# 51                          False                      False
# 52                          False                      False
# 53                          False                      False
# 54                          False                      False
# 55                          False                      False
# 56                          False                      False
# 57                          False                      False
# 58                          False                      False
# 59                          False                      False
#
#     Symptom_0_ burning_micturition  Symptom_0_ chest_pain  Symptom_0_ chills  \
# 0                            False                  False              False
# 1                            False                  False              False
# 2                            False                  False              False
# 3                            False                  False              False
# 4                            False                  False              False
# 5                            False                  False              False
# 6                            False                  False              False
# 7                            False                  False              False
# 8                            False                  False              False
# 9                            False                  False              False
# 10                           False                  False              False
# 11                           False                  False              False
# 12                           False                  False              False
# 13                           False                  False              False
# 14                           False                  False              False
# 15                           False                  False              False
# 16                           False                  False              False
# 17                           False                  False              False
# 18                           False                  False              False
# 19                           False                  False              False
# 20                           False                  False              False
# 21                           False                  False              False
# 22                           False                  False              False
# 23                           False                  False              False
# 24                           False                  False              False
# 25                           False                  False              False
# 26                           False                  False              False
# 27                           False                  False              False
# 28                           False                  False              False
# 29                           False                  False              False
# 30                           False                  False              False
# 31                           False                  False              False
# 32                           False                  False              False
# 33                           False                  False              False
# 34                           False                  False              False
# 35                           False                  False              False
# 36                           False                  False              False
# 37                           False                  False              False
# 38                           False                  False              False
# 39                           False                  False              False
# 40                           False                  False              False
# 41                           False                  False              False
# 42                           False                  False              False
# 43                           False                  False              False
# 44                           False                  False              False
# 45                           False                  False              False
# 46                           False                  False              False
# 47                           False                  False              False
# 48                           False                  False              False
# 49                           False                  False              False
# 50                           False                  False              False
# 51                           False                  False              False
# 52                           False                  False              False
# 53                           False                  False              False
# 54                           False                  False              False
# 55                           False                  False              False
# 56                           False                  False              False
# 57                           False                  False              False
# 58                           False                  False              False
# 59                           False                  False              False
#
#     Symptom_0_ constipation  Symptom_0_ continuous_sneezing  ...  \
# 0                     False                           False  ...
# 1                     False                           False  ...
# 2                     False                           False  ...
# 3                     False                           False  ...
# 4                     False                           False  ...
# 5                     False                           False  ...
# 6                     False                           False  ...
# 7                     False                           False  ...
# 8                     False                           False  ...
# 9                     False                           False  ...
# 10                    False                           False  ...
# 11                    False                           False  ...
# 12                    False                           False  ...
# 13                    False                           False  ...
# 14                    False                           False  ...
# 15                    False                           False  ...
# 16                    False                           False  ...
# 17                    False                           False  ...
# 18                    False                           False  ...
# 19                    False                            True  ...
# 20                    False                            True  ...
# 21                    False                            True  ...
# 22                    False                            True  ...
# 23                    False                           False  ...
# 24                    False                           False  ...
# 25                    False                           False  ...
# 26                    False                           False  ...
# 27                    False                           False  ...
# 28                    False                           False  ...
# 29                    False                           False  ...
# 30                    False                           False  ...
# 31                    False                           False  ...
# 32                    False                           False  ...
# 33                    False                           False  ...
# 34                    False                           False  ...
# 35                    False                           False  ...
# 36                    False                           False  ...
# 37                    False                           False  ...
# 38                    False                           False  ...
# 39                    False                           False  ...
# 40                    False                           False  ...
# 41                    False                           False  ...
# 42                    False                           False  ...
# 43                    False                           False  ...
# 44                    False                           False  ...
# 45                    False                           False  ...
# 46                    False                           False  ...
# 47                    False                           False  ...
# 48                    False                           False  ...
# 49                    False                           False  ...
# 50                    False                           False  ...
# 51                    False                           False  ...
# 52                    False                           False  ...
# 53                    False                           False  ...
# 54                    False                           False  ...
# 55                    False                           False  ...
# 56                    False                           False  ...
# 57                    False                           False  ...
# 58                    False                           False  ...
# 59                    False                           False  ...
#
#     Symptom_13_ congestion  Symptom_13_ phlegm  \
# 0                    False               False
# 1                    False               False
# 2                    False               False
# 3                    False               False
# 4                    False               False
# 5                    False               False
# 6                    False               False
# 7                    False               False
# 8                    False               False
# 9                    False               False
# 10                   False               False
# 11                   False               False
# 12                   False               False
# 13                   False               False
# 14                   False               False
# 15                   False               False
# 16                   False               False
# 17                   False               False
# 18                   False               False
# 19                   False               False
# 20                   False               False
# 21                   False               False
# 22                   False               False
# 23                   False               False
# 24                   False               False
# 25                   False               False
# 26                   False               False
# 27                   False               False
# 28                   False               False
# 29                   False               False
# 30                   False               False
# 31                   False               False
# 32                   False               False
# 33                   False               False
# 34                   False               False
# 35                   False               False
# 36                   False               False
# 37                   False               False
# 38                   False               False
# 39                   False               False
# 40                   False               False
# 41                   False               False
# 42                   False               False
# 43                   False               False
# 44                   False               False
# 45                   False               False
# 46                   False               False
# 47                   False               False
# 48                   False               False
# 49                   False               False
# 50                   False               False
# 51                   False               False
# 52                   False               False
# 53                   False               False
# 54                   False               False
# 55                   False               False
# 56                   False               False
# 57                   False               False
# 58                   False               False
# 59                   False               False
#
#     Symptom_13_ red_spots_over_body  Symptom_14_ blood_in_sputum  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# 5                             False                        False
# 6                             False                        False
# 7                             False                        False
# 8                             False                        False
# 9                             False                        False
# 10                            False                        False
# 11                            False                        False
# 12                            False                        False
# 13                            False                        False
# 14                            False                        False
# 15                            False                        False
# 16                            False                        False
# 17                            False                        False
# 18                            False                        False
# 19                            False                        False
# 20                            False                        False
# 21                            False                        False
# 22                            False                        False
# 23                            False                        False
# 24                            False                        False
# 25                            False                        False
# 26                            False                        False
# 27                            False                        False
# 28                            False                        False
# 29                            False                        False
# 30                            False                        False
# 31                            False                        False
# 32                            False                        False
# 33                            False                        False
# 34                            False                        False
# 35                            False                        False
# 36                            False                        False
# 37                            False                        False
# 38                            False                        False
# 39                            False                        False
# 40                            False                        False
# 41                            False                        False
# 42                            False                        False
# 43                            False                        False
# 44                            False                        False
# 45                            False                        False
# 46                            False                        False
# 47                            False                        False
# 48                            False                        False
# 49                            False                        False
# 50                            False                        False
# 51                            False                        False
# 52                            False                        False
# 53                            False                        False
# 54                            False                        False
# 55                            False                        False
# 56                            False                        False
# 57                            False                        False
# 58                            False                        False
# 59                            False                        False
#
#     Symptom_14_ chest_pain  Symptom_14_ loss_of_smell  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
# 5                    False                      False
# 6                    False                      False
# 7                    False                      False
# 8                    False                      False
# 9                    False                      False
# 10                   False                      False
# 11                   False                      False
# 12                   False                      False
# 13                   False                      False
# 14                   False                      False
# 15                   False                      False
# 16                   False                      False
# 17                   False                      False
# 18                   False                      False
# 19                   False                      False
# 20                   False                      False
# 21                   False                      False
# 22                   False                      False
# 23                   False                      False
# 24                   False                      False
# 25                   False                      False
# 26                   False                      False
# 27                   False                      False
# 28                   False                      False
# 29                   False                      False
# 30                   False                      False
# 31                   False                      False
# 32                   False                      False
# 33                   False                      False
# 34                   False                      False
# 35                   False                      False
# 36                   False                      False
# 37                   False                      False
# 38                   False                      False
# 39                   False                      False
# 40                   False                      False
# 41                   False                      False
# 42                   False                      False
# 43                   False                      False
# 44                   False                      False
# 45                   False                      False
# 46                   False                      False
# 47                   False                      False
# 48                   False                      False
# 49                   False                      False
# 50                   False                      False
# 51                   False                      False
# 52                   False                      False
# 53                   False                      False
# 54                   False                      False
# 55                   False                      False
# 56                   False                      False
# 57                   False                      False
# 58                   False                      False
# 59                   False                      False
#
#     Symptom_15_ blood_in_sputum  Symptom_15_ loss_of_smell  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# 5                         False                      False
# 6                         False                      False
# 7                         False                      False
# 8                         False                      False
# 9                         False                      False
# 10                        False                      False
# 11                        False                      False
# 12                        False                      False
# 13                        False                      False
# 14                        False                      False
# 15                        False                      False
# 16                        False                      False
# 17                        False                      False
# 18                        False                      False
# 19                        False                      False
# 20                        False                      False
# 21                        False                      False
# 22                        False                      False
# 23                        False                      False
# 24                        False                      False
# 25                        False                      False
# 26                        False                      False
# 27                        False                      False
# 28                        False                      False
# 29                        False                      False
# 30                        False                      False
# 31                        False                      False
# 32                        False                      False
# 33                        False                      False
# 34                        False                      False
# 35                        False                      False
# 36                        False                      False
# 37                        False                      False
# 38                        False                      False
# 39                        False                      False
# 40                        False                      False
# 41                        False                      False
# 42                        False                      False
# 43                        False                      False
# 44                        False                      False
# 45                        False                      False
# 46                        False                      False
# 47                        False                      False
# 48                        False                      False
# 49                        False                      False
# 50                        False                      False
# 51                        False                      False
# 52                        False                      False
# 53                        False                      False
# 54                        False                      False
# 55                        False                      False
# 56                        False                      False
# 57                        False                      False
# 58                        False                      False
# 59                        False                      False
#
#     Symptom_15_ muscle_pain  Symptom_16_ muscle_pain
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
# 5                     False                    False
# 6                     False                    False
# 7                     False                    False
# 8                     False                    False
# 9                     False                    False
# 10                    False                    False
# 11                    False                    False
# 12                    False                    False
# 13                    False                    False
# 14                    False                    False
# 15                    False                    False
# 16                    False                    False
# 17                    False                    False
# 18                    False                    False
# 19                    False                    False
# 20                    False                    False
# 21                    False                    False
# 22                    False                    False
# 23                    False                    False
# 24                    False                    False
# 25                    False                    False
# 26                    False                    False
# 27                    False                    False
# 28                    False                    False
# 29                    False                    False
# 30                    False                    False
# 31                    False                    False
# 32                    False                    False
# 33                    False                    False
# 34                    False                    False
# 35                    False                    False
# 36                    False                    False
# 37                    False                    False
# 38                    False                    False
# 39                    False                    False
# 40                    False                    False
# 41                    False                    False
# 42                    False                    False
# 43                    False                    False
# 44                    False                    False
# 45                    False                    False
# 46                    False                    False
# 47                    False                    False
# 48                    False                    False
# 49                    False                    False
# 50                    False                    False
# 51                    False                    False
# 52                    False                    False
# 53                    False                    False
# 54                    False                    False
# 55                    False                    False
# 56                    False                    False
# 57                    False                    False
# 58                    False                    False
# 59                    False                    False
#
# [60 rows x 408 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Disease', axis=1)
y = df['Disease']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (250, 407)
# X_test shape: (63, 407)
# y_train shape: (250,)
# y_test shape: (63,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9682539682539683

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         1
#           13       1.00      1.00      1.00         1
#           14       1.00      0.50      0.67         2
#           15       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         1
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       1.00      1.00      1.00         4
#           23       1.00      1.00      1.00         1
#           24       1.00      1.00      1.00         3
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         1
#           28       1.00      1.00      1.00         3
#           29       1.00      1.00      1.00         3
#           31       1.00      1.00      1.00         2
#           32       0.00      0.00      0.00         0
#           33       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         2
#           37       1.00      0.75      0.86         4
#           38       1.00      1.00      1.00         1
#           39       1.00      1.00      1.00         1
#           40       1.00      1.00      1.00         2
#           41       1.00      1.00      1.00         1
#
#     accuracy                           0.97        63
#    macro avg       0.94      0.92      0.93        63
# weighted avg       1.00      0.97      0.98        63
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
k = 5
knn_model = KNeighborsClassifier(n_neighbors=k)
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8095238095238095

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         2
#            5       0.00      0.00      0.00         0
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       0.00      0.00      0.00         0
#            9       1.00      1.00      1.00         1
#           10       0.00      0.00      0.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         1
#           13       1.00      1.00      1.00         1
#           14       1.00      1.00      1.00         2
#           15       0.00      0.00      0.00         1
#           17       1.00      1.00      1.00         1
#           18       1.00      0.50      0.67         2
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       0.67      0.50      0.57         4
#           23       0.33      1.00      0.50         1
#           24       1.00      0.67      0.80         3
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         1
#           28       1.00      0.33      0.50         3
#           29       1.00      1.00      1.00         3
#           30       0.00      0.00      0.00         0
#           31       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         2
#           37       1.00      0.50      0.67         4
#           38       1.00      1.00      1.00         1
#           39       1.00      1.00      1.00         1
#           40       1.00      1.00      1.00         2
#           41       1.00      1.00      1.00         1
#
#     accuracy                           0.81        63
#    macro avg       0.83      0.79      0.80        63
# weighted avg       0.90      0.81      0.84        63
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = decision_tree_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7142857142857143

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         2
#            3       0.00      0.00      0.00         0
#            6       1.00      1.00      1.00         2
#            7       0.00      0.00      0.00         2
#            9       1.00      1.00      1.00         1
#           10       1.00      0.33      0.50         3
#           11       1.00      0.67      0.80         3
#           12       1.00      1.00      1.00         1
#           13       1.00      1.00      1.00         1
#           14       0.33      0.50      0.40         2
#           15       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         1
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         1
#           20       0.75      1.00      0.86         3
#           21       1.00      1.00      1.00         1
#           22       1.00      0.50      0.67         4
#           23       0.25      1.00      0.40         1
#           24       1.00      1.00      1.00         3
#           25       1.00      0.67      0.80         3
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         1
#           28       1.00      0.33      0.50         3
#           29       1.00      0.67      0.80         3
#           31       1.00      1.00      1.00         2
#           33       0.00      0.00      0.00         1
#           34       1.00      1.00      1.00         2
#           35       1.00      0.50      0.67         2
#           37       1.00      0.50      0.67         4
#           38       1.00      1.00      1.00         1
#           39       0.50      1.00      0.67         1
#           40       1.00      0.50      0.67         2
#           41       1.00      1.00      1.00         1
#
#     accuracy                           0.71        63
#    macro avg       0.80      0.72      0.73        63
# weighted avg       0.88      0.71      0.76        63
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.naive_bayes import GaussianNB
naive_bayes_model = GaussianNB()
naive_bayes_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = naive_bayes_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9682539682539683

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         1
#           13       1.00      1.00      1.00         1
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         1
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       1.00      0.50      0.67         4
#           23       0.33      1.00      0.50         1
#           24       1.00      1.00      1.00         3
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         1
#           28       1.00      1.00      1.00         3
#           29       1.00      1.00      1.00         3
#           31       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         2
#           37       1.00      1.00      1.00         4
#           38       1.00      1.00      1.00         1
#           39       1.00      1.00      1.00         1
#           40       1.00      1.00      1.00         2
#           41       1.00      1.00      1.00         1
#
#     accuracy                           0.97        63
#    macro avg       0.98      0.98      0.97        63
# weighted avg       0.99      0.97      0.97        63

# %%
from sklearn.ensemble import VotingClassifier
ensemble_model = VotingClassifier(
    estimators=[
        ('random_forest', rf_model),
        ('knn', knn_model),
        ('decision_tree', decision_tree_model),
        ('naive_bayes', naive_bayes_model)
    ],
    voting='soft'
)

# %%
ensemble_model.fit(X_train_scaled, y_train)
# Out:
# VotingClassifier(estimators=[('random_forest',
#                               RandomForestClassifier(random_state=42)),
#                              ('knn', KNeighborsClassifier()),
#                              ('decision_tree',
#                               DecisionTreeClassifier(random_state=42)),
#                              ('naive_bayes', GaussianNB())],
#                  voting='soft')

# %%
y_pred = ensemble_model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9523809523809523
